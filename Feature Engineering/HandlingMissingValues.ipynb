# %% [markdown]
# ## Missing Values

# %% [markdown]
# In Machine Learning (ML), missing values refer to data points that are not recorded, unavailable, or lost in a dataset.
#
# They represent gaps or blanks in the data.
